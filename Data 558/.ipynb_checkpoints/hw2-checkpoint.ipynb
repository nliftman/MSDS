# %% [markdown]
# Exercise 3 - Gradient Descent function

# %%
#load libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# Load the data
file = """https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv"""
penguins = pd.read_csv(file, sep=',', header=0)
penguins = penguins.dropna()

# Create our X matrix with the predictors and y vector with the response
X = penguins.drop('body_mass_g', axis=1)
X = pd.get_dummies(X, drop_first=True)
y = penguins['body_mass_g']

#normalize the data to have mean of zero and sd of 1
mean_x = np.mean(X, axis=0)
std_x = np.std(X, axis=0)
#Avoid division by zero
std_x[std_x == 0] = 1
X_scaled = (X - mean_x) / std_x 

#do the same for the y 
mean_y = np.mean(y, axis=0)
std_y = np.std(y, axis=0)
#Avoid division by zero
y_scaled = (y - mean_y) /std_y

# Divide the data into training and test sets. By default, 25% goes into the test set.
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, random_state=0)

# %%
def computegrad(X, y, beta, lamb):
    """
    We are finding the gradient of f(beta) = 
    1/2||x*beta - y||^2 + lambda/2 * ||beta||^2
    The X is our X_training data
    y is the response vector
    beta will be given
    lam is our lambda b/c python wont let you write lambda 
    """
    return -X.T @ (y - X @ beta) + lamb * beta

# %%
def graddescent(X, y, beta_init, lamb = -5.00, step_t = .5, maxi = 1000):
    """
    We are going to now implement our computegrad function
    inside the Beta^(t+1) = Beta^t - step_t * gradient F(Beta t)
    X is a matrix that is (n,d) and is our predictors 
    y is a vector that is our output and is (n,) size
    beta_int is our initial vector
    lamb is our lambda which we used above
    step_t is our learning rate
    maxi is the maximum iterations
    
    This returns our beta as our final parameter vector 
    """
    #we will create beta and then a history so we can graph it 
    beta = beta_init.copy()
    history = [beta.copy()]
    #iterate through
    for i in range(maxi):
        grad = computegrad(X, y, beta, lam)
        beta = beta - step_t * grad
        history.append(beta.copy())
    
    return beta, history

# %% [markdown]
# What we know will happen when we run this code with a lambda = -5 is that it will not converge. We can see that in our graph below.
# HELP

# %% [markdown]
# Exercise 4 - Linear Regression

# %% [markdown]
# a. Read in the dataset. When reading in the data use the option na values=’?’. Then drop all NaN values using dropna().

# %%
#load in the libaries needed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.regressionplots import plot_fit

# %%
#read in the csv
df = pd.read_csv('/Users/naomiliftman/Desktop/MSDS/Data 558/Auto.csv', na_values = "?")
#drop the nas
df.dropna()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 1    15.0          8         350.0       165.0    3693          11.5    70
# 2    18.0          8         318.0       150.0    3436          11.0    70
# 3    16.0          8         304.0       150.0    3433          12.0    70
# 4    17.0          8         302.0       140.0    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0        86.0    2790          15.6    82
# 393  44.0          4          97.0        52.0    2130          24.6    82
# 394  32.0          4         135.0        84.0    2295          11.6    82
# 395  28.0          4         120.0        79.0    2625          18.6    82
# 396  31.0          4         119.0        82.0    2720          19.4    82
#
#      origin                       name
# ...

# %% [markdown]
# b. Use the OLS function from the statsmodels package to perform a simple linear re-
# gression with mpg as the response and weight as the predictor. Be sure to include an
# intercept. Use the summary() attribute to print the results. Comment on the output.
# For example:
# (i) Is there a relationship between the predictor and the response?
# (ii) How strong is the relationship between the predictor and the response?
# (iii) Is the relationship between the predictor and the response positive or negative?

# %%
#start by making our own data frame with the predictor and intercept
X = pd.DataFrame({'intercept': np.ones(df.shape[0]),
                  'weight': df['weight']})
X[:5]
# Out:
#    intercept  weight
# 0        1.0    3504
# 1        1.0    3693
# 2        1.0    3436
# 3        1.0    3433
# 4        1.0    3449

# %%
#pull out the variable that will be our response
y = df['mpg']
#create the model and fit it
model_1 = sm.OLS(y, X)
results = model_1.fit()
#summary attribute
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     886.6
# Date:                Tue, 14 Apr 2026   Prob (F-statistic):          5.37e-103
# Time:                        14:42:15   Log-Likelihood:                -1146.0
# No. Observations:                 397   AIC:                             2296.
# Df Residuals:                     395   BIC:                             2304.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     46.3174      0.796     58.166      0.000      44.752      47.883
# ...

# %% [markdown]
# We can see that our model's weight coefficient has a p-value that is less than our alpha level of 0.05 which means that we have statistically significant evidence to suggest there is a relationship between the weight of a car and it's miles per gallon. Looking at the coefficient on our weight variable we can see that our model predicts a decrease of 0.0077 miles per gallon for every single lb increase in the weight of our car. While the actual change in mpg is small, due to the small p-value we know that this is still strong.

# %% [markdown]
# c. Plot the response and the predictor using the plot fit function

# %%
fig, ax = plt.subplots()
fig = sm.graphics.plot_fit(results, 1, ax=ax)
ax.set_ylabel("MPG")
ax.set_xlabel("Weight")
ax.set_title("Linear Regression")
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %% [markdown]
# (d) Plot the residuals vs. fitted values. Comment on any problems you see with the fit.

# %%
plt.scatter(results.fittedvalues, results.resid)

# %% [markdown]
# What we can see is that there is not an even spread of the residuals around the zero line. When the fitted values get closer to 10 the residuals are distributed around the 0 line between -5 and 5; however, when the fitted values gets closer to 30 and 35 we can see the spread of the residuals increasing to between -10 and 15.
